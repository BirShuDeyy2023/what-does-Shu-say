# %%
import csv
import json
import pandas as pd

# %%
csv_file_path = "./collect_form2.csv"
json_file_path = "./collect_form.txt"

# 讀取 CSV 檔案並轉換為 Python 字典的列表
csv_data = []
with open(csv_file_path, "r",encoding="utf-8") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        csv_data.append(row)

# %%
csv_data
# Out:
# [{'\ufeffno': '1',
#   'voice_name': '💜 banene - minion voice',
#   'stream_name': '2022/07/26 shu yamino organized neatly',
#   'stream_link': 'https://www.youtube.com/watch?v=GvBPFY3altg&t=10821s',
#   'unlock_img': '(1)',
#   'voice_id': 'spvoice_1'},
#  {'\ufeffno': '2',
#   'voice_name': 'BOOBIES!',
#   'stream_name': '2022/01/23 【📻📶】first horror game stream (The Radio Station)',
#   'stream_link': 'https://www.youtube.com/watch?v=4TLRTBpsjmg&t=2988s',
#   'unlock_img': '(2)',
#   'voice_id': 'norvoice_1'},
#  {'\ufeffno': '3',
#   'voice_name': "eyy baby it's me shu yamino",
#   'stream_name': '2021/12/22 how i got here',
#   'stream_link': 'https://www.youtube.com/watch?v=NkbG17qCTSA&t=7s',
#   'unlock_img': '(3)',
#   'voice_id': 'norvoice_2'},
#  {'\ufeffno': '4',
#   'voice_name': '💜 gottem',
#   'stream_name': '2022/04/27 how many bananas did we get (Just Chatting)',
#   'stream_link': 'https://www.youtube.com/watch?v=BTNvN_nK9eI&t=2553s',
#   'unlock_img': '(4)',
#   'voice_id': 'spvoice_2'},
#  {'\ufeffno': '5',
#   'voice_name': 'hehe',
#   'stream_name': '2022/11/02 Listening to stories... (Coffee Talk pt. 2)',
#   'stream_link': 'https://www.youtube.com/watch?v=1On2Foa5FNo&t=10744s',
#   'unlock_img': '(5)',
#   'voice_id': 'norvoice_3'},
#  {'\ufeffno': '6',
#   'voice_name': 'HUH!!!!',
#   'stream_name': '2022/11/10 Apex Legends... with a twist?',
#   'stream_link': 'https://www.youtube.com/watch?v=fi7BrMLb2C0&t=10075s',
#   'unlock_img': '(6)',
#   'voice_id': 'norvoice_4'},
#  {'\ufeffno': '7',
#   'voice_name': '💜 I could drive!!!!!',
#   'stream_name': '2022/03/21 i get 8th or lower = im a bad driver (Mario Kart 8 Deluxe)',
#   'stream_link': 'https://www.youtube.com/watch?v=dPqzkNsafJc&t=2290s',
#   'unlock_img': '(7)',
#   'voice_id': 'sp_voice_3'},
#  {'\ufeffno': '8',
#   'voice_name': 'I trust my yaminions',
#   'stream_name': '2022/08/01 Men of a Certain Age Gravitationally Pulled Downwards (Fall Guys)',
#   'stream_link': 'https://www.youtube.com/watch?v=YlA4mJ-d8eA&t=6338s',
#   'unlock_img': '(8)',
#   'voice_id': 'norvoice_5'},
#  {'\ufeffno': '9',
#   'voice_name': 'ICU PEE',
#   'stream_name': '2023/01/22 【#WrestleSanji2023】 making myself',
#   'stream_link': 'https://www.youtube.com/watch?v=H-YZFB3cr-I&t=6980s',
#   'unlock_img': '(9)',
#   'voice_id': 'norvoice_6'},
#  {'\ufeffno': '10',
#   'voice_name': "💜 I'm a nerd!!!",
#   'stream_name': "2022/12/03 lmao Valorant LET'S GO",
#   'stream_link': 'https://www.youtube.com/watch?v=Hwvb3v0O5ys&t=11776s',
#   'unlock_img': '(10)',
#   'voice_id': 'spvoice_4'},
#  {'\ufeffno': '11',
#   'voice_name': "I'm harder when I'm not drunk",
#   'stream_name': '2022/09/17 We are Valorant',
#   'stream_link': 'https://www.youtube.com/watch?v=NaZrD9lxby8&t=14125s',
#   'unlock_img': '(11)',
#   'voice_id': 'norvoice_7'},
#  {'\ufeffno': '12',
#   'voice_name': "It's a chicken mug!!",
#   'stream_name': '2022/06/04 mug. (Minecraft)',
#   'stream_link': 'https://www.youtube.com/watch?v=8KNCiv3qevk&t=7648s',
#   'unlock_img': '(12)',
#   'voice_id': 'norvoice_8'},
#  {'\ufeffno': '13',
#   'voice_name': 'lemongrab hbd',
#   'stream_name': '2022/06/16 5V5 VALO CUSTOM 2ND SEASON',
#   'stream_link': 'https://www.youtube.com/watch?v=TxZ62ShjEg0&t=19452s',
#   'unlock_img': '(13)',
#   'voice_id': 'norvoice_9'},
#  {'\ufeffno': '14',
#   'voice_name': 'mgmg',
#   'stream_name': '2023/01/22 【#WrestleSanji2023】 making myself',
#   'stream_link': 'https://www.youtube.com/watch?v=H-YZFB3cr-I&t=13158s',
#   'unlock_img': '(14)',
#   'voice_id': 'norvoice_10'},
#  {'\ufeffno': '15',
#   'voice_name': '💜 nya - lemongrab',
#   'stream_name': '2022/05/26 yoink yoink (actually Jump King)',
#   'stream_link': 'https://www.youtube.com/watch?v=jNugczJi9d0&t=5475s',
#   'unlock_img': '(15)',
#   'voice_id': 'spvoice_5'},
#  {'\ufeffno': '16',
#   'voice_name': 'nya without emo',
#   'stream_name': '2022/05/24 how many valorant stream titles can I come up with (Valorant)',
#   'stream_link': 'https://www.youtube.com/watch?v=UCahY1BcLKE&t=21006s',
#   'unlock_img': '(16)',
#   'voice_id': 'norvoice_11'},
#  {'\ufeffno': '17',
#   'voice_name': 'oh oh sorcery spooky',
#   'stream_name': '2022/02/21 FULL LOBBY OVERWATCH! (Overwatch Collab)',
#   'stream_link': 'https://www.youtube.com/watch?v=LcDRKUxiffs&t=24985s',
#   'unlock_img': '(17)',
#   'voice_id': 'norvoice_12'},
#  {'\ufeffno': '18',
#   'voice_name': 'shall we cheers',
#   'stream_name': '2022/07/29 THE ??? + MILK TIER LIST',
#   'stream_link': 'https://www.youtube.com/watch?v=N7yIm7pH0hI&t=1135s',
#   'unlock_img': '(18)',
#   'voice_id': 'norvoice_13'},
#  {'\ufeffno': '19',
#   'voice_name': 'Shu let me do it for you',
#   'stream_name': '2023/01/24 【Valorant】 Can The Cyborg Still Concussy?',
#   'stream_link': 'https://www.youtube.com/watch?v=0Hy8WZyPtCU&list=PLt-RaSHMkJEmQdO4MMVOFPMgPTAwQ55b1&index=44&t=9165s',
#   'unlock_img': '(19)',
#   'voice_id': 'norvoice_14'},
#  {'\ufeffno': '20',
#   'voice_name': 'shut up this guy',
#   'stream_name': '2023/01/09 moregon (The Oregon Trail pt. 2)',
#   'stream_link': 'https://www.youtube.com/watch?v=1UTGM7EsNBo&t=9613s',
#   'unlock_img': '(20)',
#   'voice_id': 'norvoice_15'},
#  {'\ufeffno': '21',
#   'voice_name': 'UR MOM',
#   'stream_name': '2021/12/20 【DEBUT】i’m shu yamino',
#   'stream_link': 'https://www.youtube.com/watch?v=Lmdz1C1rzXM&t=268s',
#   'unlock_img': '(21)',
#   'voice_id': 'norvoice_16'},
#  {'\ufeffno': '22',
#   'voice_name': 'wake up yaminion',
#   'stream_name': '2022/09/20 squidding around (Splatoon 3)',
#   'stream_link': 'https://www.youtube.com/watch?v=zOkDdjyIppM&t=10088s',
#   'unlock_img': '(22)',
#   'voice_id': 'norvoice_17'},
#  {'\ufeffno': '23',
#   'voice_name': "you don't want to see me get mad",
#   'stream_name': '2022/05/26 yoink yoink (actually Jump King)',
#   'stream_link': 'https://www.youtube.com/watch?v=jNugczJi9d0&t=2754s',
#   'unlock_img': '(23)',
#   'voice_id': 'norvoice_18'},
#  {'\ufeffno': '24',
#   'voice_name': "YOU'RE STILL ALIVE!!!",
#   'stream_name': '2022/03/20 swerve zombies (Project Zomboid Collab!)',
#   'stream_link': 'https://www.youtube.com/watch?v=WCM-q3sqNTQ&t=8462s',
#   'unlock_img': '(24)',
#   'voice_id': 'norvoice_19'},
#  {'\ufeffno': '25',
#   'voice_name': "you're such a baka",
#   'stream_name': '2023/01/22 【#WrestleSanji2023】 making myself',
#   'stream_link': 'https://www.youtube.com/watch?v=H-YZFB3cr-I&t=12258s',
#   'unlock_img': '(25)',
#   'voice_id': 'norvoice_20'},
#  {'\ufeffno': '26',
#   'voice_name': 'goose sound',
#   'stream_name': '2022/08/19 NijiEN Goose Goose Duck!! (Shu POV)',
#   'stream_link': 'https://www.youtube.com/watch?v=ZGYue2USQng&t=2748s',
#   'unlock_img': '(26)',
#   'voice_id': 'norvoice_21'},
#  {'\ufeffno': '27',
#   'voice_name': '破防daipan',
#   'stream_name': '2022/08/11 hummus (Metroid Dread)',
#   'stream_link': 'https://www.youtube.com/watch?v=j6VvqhZkcWw&t=15799s',
#   'unlock_img': '(27)',
#   'voice_id': 'norvoice_22'},
#  {'\ufeffno': '28',
#   'voice_name': '💜 痛痛飛走了',
#   'stream_name': '2022/02/17 snorlax squad (Pokémon Legends: Arceus pt. 4)',
#   'stream_link': 'https://www.youtube.com/watch?v=j0ZgTZGau1I&t=23390s',
#   'unlock_img': '(28)',
#   'voice_id': 'spvoice_6'},
#  {'\ufeffno': '29',
#   'voice_name': '圓周率',
#   'stream_name': '2022/03/12 BANANA SURVIVAL?? - this is shu yamino btw not banana (Project Zomboid)',
#   'stream_link': 'https://www.youtube.com/watch?v=0BxpwZ5RsiM&t=11829s',
#   'unlock_img': '(29)',
#   'voice_id': 'norvoice_23'},
#  {'\ufeffno': '30',
#   'voice_name': 'Shu據機',
#   'stream_name': '2023/04/16 House Flipper!',
#   'stream_link': 'https://www.youtube.com/watch?v=cFpXhB2qnkc&t=1747s',
#   'unlock_img': '(30)',
#   'voice_id': 'norvoice_24'},
#  {'\ufeffno': '',
#   'voice_name': '',
#   'stream_name': '',
#   'stream_link': '',
#   'unlock_img': '',
#   'voice_id': ''},
#  {'\ufeffno': '',
#   'voice_name': '',
#   'stream_name': '',
#   'stream_link': '',
#   'unlock_img': '',
#   'voice_id': ''},
#  {'\ufeffno': '',
#   'voice_name': '',
#   'stream_name': '',
#   'stream_link': '',
#   'unlock_img': '',
#   'voice_id': ''},
#  {'\ufeffno': '',
#   'voice_name': '',
#   'stream_name': '',
#   'stream_link': '',
#   'unlock_img': '',
#   'voice_id': ''},
#  {'\ufeffno': '',
#   'voice_name': '',
#   'stream_name': '',
#   'stream_link': '',
#   'unlock_img': '',
#   'voice_id': ''},
#  {'\ufeffno': '',
#   'voice_name': '',
#   'stream_name': '',
#   'stream_link': '',
#   'unlock_img': '',
#   'voice_id': ''}]

# %%
# 將 Python 字典的列表轉換為 JSON，並儲存到檔案
with open(json_file_path, "w",encoding="utf-8") as json_file:
    json.dump(csv_data, json_file, ensure_ascii=False)

# %%
csv_file_path = "./randomNo_to_No.csv"
json_file_path = "./collect_form_no.txt"

# 讀取 CSV 檔案並轉換為 Python 字典的列表
csv_data = []
with open(csv_file_path, "r",encoding="utf-8") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        csv_data.append(row)

# %%
csv_data
# Out:
# [{'\ufeffnewRandomNumber': '1',
#   'no': '1',
#   'voice_name': '💜 banene - minion voice',
#   'stream_name': '2022/07/26 shu yamino organized neatly',
#   'stream_link': 'https://www.youtube.com/watch?v=GvBPFY3altg&t=10821s',
#   'unlock_img': '(1)',
#   'voice_id': 'spvoice_1'},
#  {'\ufeffnewRandomNumber': '2',
#   'no': '4',
#   'voice_name': '💜 gottem',
#   'stream_name': '2022/04/27 how many bananas did we get (Just Chatting)',
#   'stream_link': 'https://www.youtube.com/watch?v=BTNvN_nK9eI&t=2553s',
#   'unlock_img': '(4)',
#   'voice_id': 'spvoice_2'},
#  {'\ufeffnewRandomNumber': '3',
#   'no': '7',
#   'voice_name': '💜 I could drive!!!!!',
#   'stream_name': '2022/03/21 i get 8th or lower = im a bad driver (Mario Kart 8 Deluxe)',
#   'stream_link': 'https://www.youtube.com/watch?v=dPqzkNsafJc&t=2290s',
#   'unlock_img': '(7)',
#   'voice_id': 'sp_voice_3'},
#  {'\ufeffnewRandomNumber': '4',
#   'no': '10',
#   'voice_name': "💜 I'm a nerd!!!",
#   'stream_name': "2022/12/03 lmao Valorant LET'S GO",
#   'stream_link': 'https://www.youtube.com/watch?v=Hwvb3v0O5ys&t=11776s',
#   'unlock_img': '(10)',
#   'voice_id': 'spvoice_4'},
#  {'\ufeffnewRandomNumber': '5',
#   'no': '15',
#   'voice_name': '💜 nya - lemongrab',
#   'stream_name': '2022/05/26 yoink yoink (actually Jump King)',
#   'stream_link': 'https://www.youtube.com/watch?v=jNugczJi9d0&t=5475s',
#   'unlock_img': '(15)',
#   'voice_id': 'spvoice_5'},
#  {'\ufeffnewRandomNumber': '6',
#   'no': '28',
#   'voice_name': '💜 痛痛飛走了',
#   'stream_name': '2022/02/17 snorlax squad (Pokémon Legends: Arceus pt. 4)',
#   'stream_link': 'https://www.youtube.com/watch?v=j0ZgTZGau1I&t=23390s',
#   'unlock_img': '(28)',
#   'voice_id': 'spvoice_6'},
#  {'\ufeffnewRandomNumber': '7',
#   'no': '2',
#   'voice_name': 'BOOBIES!',
#   'stream_name': '2022/01/23 【📻📶】first horror game stream (The Radio Station)',
#   'stream_link': 'https://www.youtube.com/watch?v=4TLRTBpsjmg&t=2988s',
#   'unlock_img': '(2)',
#   'voice_id': 'norvoice_1'},
#  {'\ufeffnewRandomNumber': '8',
#   'no': '3',
#   'voice_name': "eyy baby it's me shu yamino",
#   'stream_name': '2021/12/22 how i got here',
#   'stream_link': 'https://www.youtube.com/watch?v=NkbG17qCTSA&t=7s',
#   'unlock_img': '(3)',
#   'voice_id': 'norvoice_2'},
#  {'\ufeffnewRandomNumber': '9',
#   'no': '5',
#   'voice_name': 'hehe',
#   'stream_name': '2022/11/02 Listening to stories... (Coffee Talk pt. 2)',
#   'stream_link': 'https://www.youtube.com/watch?v=1On2Foa5FNo&t=10744s',
#   'unlock_img': '(5)',
#   'voice_id': 'norvoice_3'},
#  {'\ufeffnewRandomNumber': '10',
#   'no': '6',
#   'voice_name': 'HUH!!!!',
#   'stream_name': '2022/11/10 Apex Legends... with a twist?',
#   'stream_link': 'https://www.youtube.com/watch?v=fi7BrMLb2C0&t=10075s',
#   'unlock_img': '(6)',
#   'voice_id': 'norvoice_4'},
#  {'\ufeffnewRandomNumber': '11',
#   'no': '8',
#   'voice_name': 'I trust my yaminions',
#   'stream_name': '2022/08/01 Men of a Certain Age Gravitationally Pulled Downwards (Fall Guys)',
#   'stream_link': 'https://www.youtube.com/watch?v=YlA4mJ-d8eA&t=6338s',
#   'unlock_img': '(8)',
#   'voice_id': 'norvoice_5'},
#  {'\ufeffnewRandomNumber': '12',
#   'no': '9',
#   'voice_name': 'ICU PEE',
#   'stream_name': '2023/01/22 【#WrestleSanji2023】 making myself',
#   'stream_link': 'https://www.youtube.com/watch?v=H-YZFB3cr-I&t=6980s',
#   'unlock_img': '(9)',
#   'voice_id': 'norvoice_6'},
#  {'\ufeffnewRandomNumber': '13',
#   'no': '11',
#   'voice_name': "I'm harder when I'm not drunk",
#   'stream_name': '2022/09/17 We are Valorant',
#   'stream_link': 'https://www.youtube.com/watch?v=NaZrD9lxby8&t=14125s',
#   'unlock_img': '(11)',
#   'voice_id': 'norvoice_7'},
#  {'\ufeffnewRandomNumber': '14',
#   'no': '12',
#   'voice_name': "It's a chicken mug!!",
#   'stream_name': '2022/06/04 mug. (Minecraft)',
#   'stream_link': 'https://www.youtube.com/watch?v=8KNCiv3qevk&t=7648s',
#   'unlock_img': '(12)',
#   'voice_id': 'norvoice_8'},
#  {'\ufeffnewRandomNumber': '15',
#   'no': '13',
#   'voice_name': 'lemongrab hbd',
#   'stream_name': '2022/06/16 5V5 VALO CUSTOM 2ND SEASON',
#   'stream_link': 'https://www.youtube.com/watch?v=TxZ62ShjEg0&t=19452s',
#   'unlock_img': '(13)',
#   'voice_id': 'norvoice_9'},
#  {'\ufeffnewRandomNumber': '16',
#   'no': '14',
#   'voice_name': 'mgmg',
#   'stream_name': '2023/01/22 【#WrestleSanji2023】 making myself',
#   'stream_link': 'https://www.youtube.com/watch?v=H-YZFB3cr-I&t=13158s',
#   'unlock_img': '(14)',
#   'voice_id': 'norvoice_10'},
#  {'\ufeffnewRandomNumber': '17',
#   'no': '16',
#   'voice_name': 'nya without emo',
#   'stream_name': '2022/05/24 how many valorant stream titles can I come up with (Valorant)',
#   'stream_link': 'https://www.youtube.com/watch?v=UCahY1BcLKE&t=21006s',
#   'unlock_img': '(16)',
#   'voice_id': 'norvoice_11'},
#  {'\ufeffnewRandomNumber': '18',
#   'no': '17',
#   'voice_name': 'oh oh sorcery spooky',
#   'stream_name': '2022/02/21 FULL LOBBY OVERWATCH! (Overwatch Collab)',
#   'stream_link': 'https://www.youtube.com/watch?v=LcDRKUxiffs&t=24985s',
#   'unlock_img': '(17)',
#   'voice_id': 'norvoice_12'},
#  {'\ufeffnewRandomNumber': '19',
#   'no': '18',
#   'voice_name': 'shall we cheers',
#   'stream_name': '2022/07/29 THE ??? + MILK TIER LIST',
#   'stream_link': 'https://www.youtube.com/watch?v=N7yIm7pH0hI&t=1135s',
#   'unlock_img': '(18)',
#   'voice_id': 'norvoice_13'},
#  {'\ufeffnewRandomNumber': '20',
#   'no': '19',
#   'voice_name': 'Shu let me do it for you',
#   'stream_name': '2023/01/24 【Valorant】 Can The Cyborg Still Concussy?',
#   'stream_link': 'https://www.youtube.com/watch?v=0Hy8WZyPtCU&list=PLt-RaSHMkJEmQdO4MMVOFPMgPTAwQ55b1&index=44&t=9165s',
#   'unlock_img': '(19)',
#   'voice_id': 'norvoice_14'},
#  {'\ufeffnewRandomNumber': '21',
#   'no': '20',
#   'voice_name': 'shut up this guy',
#   'stream_name': '2023/01/09 moregon (The Oregon Trail pt. 2)',
#   'stream_link': 'https://www.youtube.com/watch?v=1UTGM7EsNBo&t=9613s',
#   'unlock_img': '(20)',
#   'voice_id': 'norvoice_15'},
#  {'\ufeffnewRandomNumber': '22',
#   'no': '21',
#   'voice_name': 'UR MOM',
#   'stream_name': '2021/12/20 【DEBUT】i’m shu yamino',
#   'stream_link': 'https://www.youtube.com/watch?v=Lmdz1C1rzXM&t=268s',
#   'unlock_img': '(21)',
#   'voice_id': 'norvoice_16'},
#  {'\ufeffnewRandomNumber': '23',
#   'no': '22',
#   'voice_name': 'wake up yaminion',
#   'stream_name': '2022/09/20 squidding around (Splatoon 3)',
#   'stream_link': 'https://www.youtube.com/watch?v=zOkDdjyIppM&t=10088s',
#   'unlock_img': '(22)',
#   'voice_id': 'norvoice_17'},
#  {'\ufeffnewRandomNumber': '24',
#   'no': '23',
#   'voice_name': "you don't want to see me get mad",
#   'stream_name': '2022/05/26 yoink yoink (actually Jump King)',
#   'stream_link': 'https://www.youtube.com/watch?v=jNugczJi9d0&t=2754s',
#   'unlock_img': '(23)',
#   'voice_id': 'norvoice_18'},
#  {'\ufeffnewRandomNumber': '25',
#   'no': '24',
#   'voice_name': "YOU'RE STILL ALIVE!!!",
#   'stream_name': '2022/03/20 swerve zombies (Project Zomboid Collab!)',
#   'stream_link': 'https://www.youtube.com/watch?v=WCM-q3sqNTQ&t=8462s',
#   'unlock_img': '(24)',
#   'voice_id': 'norvoice_19'},
#  {'\ufeffnewRandomNumber': '26',
#   'no': '25',
#   'voice_name': "you're such a baka",
#   'stream_name': '2023/01/22 【#WrestleSanji2023】 making myself',
#   'stream_link': 'https://www.youtube.com/watch?v=H-YZFB3cr-I&t=12258s',
#   'unlock_img': '(25)',
#   'voice_id': 'norvoice_20'},
#  {'\ufeffnewRandomNumber': '27',
#   'no': '26',
#   'voice_name': 'goose sound',
#   'stream_name': '2022/08/19 NijiEN Goose Goose Duck!! (Shu POV)',
#   'stream_link': 'https://www.youtube.com/watch?v=ZGYue2USQng&t=2748s',
#   'unlock_img': '(26)',
#   'voice_id': 'norvoice_21'},
#  {'\ufeffnewRandomNumber': '28',
#   'no': '27',
#   'voice_name': '破防daipan',
#   'stream_name': '2022/08/11 hummus (Metroid Dread)',
#   'stream_link': 'https://www.youtube.com/watch?v=j6VvqhZkcWw&t=15799s',
#   'unlock_img': '(27)',
#   'voice_id': 'norvoice_22'},
#  {'\ufeffnewRandomNumber': '29',
#   'no': '29',
#   'voice_name': '圓周率',
#   'stream_name': '2022/03/12 BANANA SURVIVAL?? - this is shu yamino btw not banana (Project Zomboid)',
#   'stream_link': 'https://www.youtube.com/watch?v=0BxpwZ5RsiM&t=11829s',
#   'unlock_img': '(29)',
#   'voice_id': 'norvoice_23'},
#  {'\ufeffnewRandomNumber': '30',
#   'no': '30',
#   'voice_name': 'Shu據機',
#   'stream_name': '2023/04/16 House Flipper!',
#   'stream_link': 'https://www.youtube.com/watch?v=cFpXhB2qnkc&t=1747s',
#   'unlock_img': '(30)',
#   'voice_id': 'norvoice_24'}]

# %%
# 將 Python 字典的列表轉換為 JSON，並儲存到檔案
with open(json_file_path, "w",encoding="utf-8") as json_file:
    json.dump(csv_data, json_file, ensure_ascii=False)
